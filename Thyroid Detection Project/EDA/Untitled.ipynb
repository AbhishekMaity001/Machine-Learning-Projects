# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import os

# %%
pd.set_option('display.max_columns',None)

# %%
df=pd.read_csv(r'D:\Data Science\Machine-Learning-Projects\Thyroid Detection Project\Prediction_File_From_DB\InputFile.csv')
df.head()
# Out:
#    age sex on_thyroxine query_on_thyroxine on_antithyroid_medication sick  \
# 0   44   M            f                  f                         f    f
# 1   48   M            f                  t                         f    f
# 2   61   F            f                  f                         f    f
# 3   35   F            t                  f                         f    f
# 4   70   F            f                  f                         f    t
#
#   pregnant thyroid_surgery I131_treatment query_hypothyroid  \
# 0        f               f              f                 f
# 1        f               f              f                 f
# 2        f               f              f                 f
# 3        f               f              f                 f
# 4        f               f              f                 f
#
#   query_hyperthyroid lithium goitre tumor hypopituitary psych TSH_measured  \
# 0                  f       f      f     f             f     f            t
# ...

# %%
df.columns
# Out:
# Index(['age', 'sex', 'on_thyroxine', 'query_on_thyroxine',
#        'on_antithyroid_medication', 'sick', 'pregnant', 'thyroid_surgery',
#        'I131_treatment', 'query_hypothyroid', 'query_hyperthyroid', 'lithium',
#        'goitre', 'tumor', 'hypopituitary', 'psych', 'TSH_measured', 'TSH',
#        'T3_measured', 'T3', 'TT4_measured', 'TT4', 'T4U_measured', 'T4U',
#        'FTI_measured', 'FTI', 'TBG_measured', 'TBG', 'referral_source'],
#       dtype='object')

# %%
df.shape
# Out:
# (259, 29)

# %%
df.isnull().sum()
# Out:
# age                          0
# sex                          0
# on_thyroxine                 0
# query_on_thyroxine           0
# on_antithyroid_medication    0
# sick                         0
# pregnant                     0
# thyroid_surgery              0
# I131_treatment               0
# query_hypothyroid            0
# query_hyperthyroid           0
# lithium                      0
# goitre                       0
# tumor                        0
# hypopituitary                0
# psych                        0
# TSH_measured                 0
# TSH                          0
# T3_measured                  0
# T3                           0
# TT4_measured                 0
# TT4                          0
# T4U_measured                 0
# T4U                          0
# FTI_measured                 0
# FTI                          0
# TBG_measured                 0
# TBG                          0
# referral_source              0
# dtype: int64

# %%
df = pd.read_csv('hypothyroid.csv')
df.head()
# Out:
#   age sex on_thyroxine query_on_thyroxine on_antithyroid_medication sick  \
# 0  41   F            f                  f                         f    f
# 1  23   F            f                  f                         f    f
# 2  46   M            f                  f                         f    f
# 3  70   F            t                  f                         f    f
# 4  70   F            f                  f                         f    f
#
#   pregnant thyroid_surgery I131_treatment query_hypothyroid  \
# 0        f               f              f                 f
# 1        f               f              f                 f
# 2        f               f              f                 f
# 3        f               f              f                 f
# 4        f               f              f                 f
#
#   query_hyperthyroid lithium goitre tumor hypopituitary psych TSH_measured  \
# 0                  f       f      f     f             f     f            t
# ...

# %%
len(df['sex'].unique())
# Out:
# 3

# %%
df['sex'].value_counts()
# Out:
# F    2480
# M    1142
# ?     150
# Name: sex, dtype: int64

# %%
d = pd.get_dummies(df['sex'])
d
# Out:
#       ?  F  M
# 0     0  1  0
# 1     0  1  0
# 2     0  0  1
# 3     0  1  0
# 4     0  1  0
# ...  .. .. ..
# 3767  0  1  0
# 3768  0  1  0
# 3769  0  1  0
# 3770  0  0  1
# 3771  0  1  0
#
# [3772 rows x 3 columns]

# %%
df = pd.get_dummies(df,columns=['referral_source'])
df
# Out:
#      age sex on_thyroxine query_on_thyroxine on_antithyroid_medication sick  \
# 0     41   F            f                  f                         f    f
# 1     23   F            f                  f                         f    f
# 2     46   M            f                  f                         f    f
# 3     70   F            t                  f                         f    f
# 4     70   F            f                  f                         f    f
# ...   ..  ..          ...                ...                       ...  ...
# 3767  30   F            f                  f                         f    f
# 3768  68   F            f                  f                         f    f
# 3769  74   F            f                  f                         f    f
# 3770  72   M            f                  f                         f    f
# 3771  64   F            f                  f                         f    f
#
# ...

# %%
for col in df.columns:
    if df[col].nunique() > 2:
        print(col)
# Out:
# age
# sex
# TSH
# T3
# TT4
# T4U
# FTI
# referral_source
# Class

# %%
df.shape
# Out:
# (3772, 30)

# %%
df['referral_source'].value_counts()
# Out:
# other    2201
# SVI      1034
# SVHC      386
# STMW      112
# SVHD       39
# Name: referral_source, dtype: int64

# %%
df['Class'].value_counts()
# Out:
# negative                   3481
# compensated_hypothyroid     194
# primary_hypothyroid          95
# secondary_hypothyroid         2
# Name: Class, dtype: int64

# %%
onlyfiles = [f for f in os.listdir('D:\Data Science\Machine-Learning-Projects\Thyroid Detection Project\Prediction_Batch_Files') ]

# %%
onlyfiles
# Out:
# ['hypothyroid_0102062112000.csv',
#  'hypothyroid_02111.csv',
#  'hypothyroid_0211198_0102062.csv',
#  'hypothyroid_0211198_0102062112025.csv',
#  'hypothyroid_0211198_0102062112042.csv',
#  'hypothyroid_0211198_0102062112097.csv',
#  'hypothyroid_0211198_0102062112109.csv',
#  'wafer_0211198_0102062112001.csv',
#  '_0211198_0102062112004.csv']

# %%
import re
regex = "hypothyroid_{1}\d{7}_\d{13}.csv"
for i in onlyfiles:
    if re.match(regex,i):
        print(i)
# Out:
# hypothyroid_0211198_0102062112025.csv
# hypothyroid_0211198_0102062112042.csv
# hypothyroid_0211198_0102062112097.csv
# hypothyroid_0211198_0102062112109.csv

# %%
onlyfiles = [f for f in os.listdir('D:\Data Science\Machine-Learning-Projects\Thyroid Detection Project\Prediction_Raw_Files_Validated/Good_Raw/') ]

# %%
onlyfiles
# Out:
# ['hypothyroid_0211198_0102062112025.csv',
#  'hypothyroid_0211198_0102062112042.csv',
#  'hypothyroid_0211198_0102062112097.csv',
#  'hypothyroid_0211198_0102062112109.csv']

# %%
df = pd.read_csv('D:\Data Science\Machine-Learning-Projects\Thyroid Detection Project\Prediction_Raw_Files_Validated/Good_Raw/hypothyroid_0211198_0102062112025.csv')
df.shape
# Out:
# (172, 25)

# %%
df = pd.read_csv('D:\Data Science\Machine-Learning-Projects\Thyroid Detection Project\Prediction_Raw_Files_Validated/Good_Raw/hypothyroid_0211198_0102062112042.csv')
df.shape
# Out:
# (200, 26)

# %%
df = pd.read_csv('D:\Data Science\Machine-Learning-Projects\Thyroid Detection Project\Prediction_Raw_Files_Validated/Good_Raw/hypothyroid_0211198_0102062112097.csv')
df.shape
# Out:
# (259, 29)

# %%
df = pd.read_csv('D:\Data Science\Machine-Learning-Projects\Thyroid Detection Project\Prediction_Raw_Files_Validated/Good_Raw/hypothyroid_0211198_0102062112109.csv')
df.shape
# Out:
# (200, 9)
